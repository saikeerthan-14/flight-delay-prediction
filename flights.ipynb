# %%
import pandas as pd

# %%
df = pd.read_csv("./data/departures/LGA/Detailed_Statistics_Departures.csv", skiprows=7, skipfooter=1, engine="python")
df
# Out:
#        Carrier Code Date (MM/DD/YYYY)  Flight Number Tail Number  \
# 0                9E        01/01/2019           3287      N295PQ
# 1                9E        01/01/2019           3324      N294PQ
# 2                9E        01/01/2019           3325      N341PQ
# 3                9E        01/01/2019           3424      N8976E
# 4                9E        01/01/2019           3438      N917XJ
# ...             ...               ...            ...         ...
# 112806           9E        12/31/2023           5407      N490PX
# 112807           9E        12/31/2023           5408      N490PX
# 112808           9E        12/31/2023           5461      N912XJ
# 112809           9E        12/31/2023           5499      N134EV
# 112810           9E        12/31/2023           5516      N919XJ
#
#        Destination Airport Scheduled departure time Actual departure time  \
# 0                      CVG                    15:55                 15:51
# ...

# %%
df[df["Destination Airport"] == "SYR"]
# Out:
#        Carrier Code Date (MM/DD/YYYY)  Flight Number Tail Number  \
# 25               9E        01/01/2020           4893      N317CA
# 28               9E        01/01/2020           4902      N981EV
# 47               9E        01/01/2022           4881      N918XJ
# 82               9E        01/01/2023           4992      N606LR
# 107              9E        01/02/2019           5018      N980EV
# ...             ...               ...            ...         ...
# 112628           9E        12/30/2022           4992      N925XJ
# 112704           9E        12/30/2023           5519      N147PQ
# 112715           9E        12/31/2019           4893      N668CA
# 112732           9E        12/31/2019           5432      N981EV
# 112769           9E        12/31/2022           4992      N326PQ
#
#        Destination Airport Scheduled departure time Actual departure time  \
# 25                     SYR                    17:05                 16:58
# ...

# %%
# temp_df[temp_df["Destination Airport"] == "SYR"]
temp_df
# Out:
#       Carrier Code Date (MM/DD/YYYY)  Flight Number Tail Number  \
# 123             YX        01/01/2022           5008      N405YX
# 897             YX        01/08/2022           4686      N405YX
# 1505            YX        01/14/2023           4740      N438YX
# 1603            YX        01/15/2022           4686      N443YX
# 2210            YX        01/21/2023           4740      N116HQ
# 2308            YX        01/22/2022           4686      N124HQ
# 2914            YX        01/28/2023           4740      N129HQ
# 3012            YX        01/29/2022           4686      N118HQ
# 3722            YX        02/05/2022           4783      N451YX
# 4435            YX        02/12/2022           4783      N407YX
# 5190            YX        02/19/2022           4783      N411YX
# 5948            YX        02/26/2022           4783      N429YX
# 6731            YX        03/05/2022           4509      N120HQ
# 7496            YX        03/12/2022           4509      N404YX
# ...

# %%
departures_df = pd.concat(departure_df_list).reset_index(drop=True)
departures_df
# Out:
#       Carrier Code Date (MM/DD/YYYY)  Flight Number Tail Number  \
# 0               G4        01/02/2020           1737       241NV
# 1               G4        01/03/2019           1720       226NV
# 2               G4        01/03/2021           1744       245NV
# 3               G4        01/03/2022            962       222NV
# 4               G4        01/03/2023            523       234NV
# ...            ...               ...            ...         ...
# 56537           YX        12/16/2023           4312      N128HQ
# 56538           YX        12/18/2021           5008      N127HQ
# 56539           YX        12/23/2023           4371      N102HQ
# 56540           YX        12/25/2021           5008      N425YX
# 56541           YX        12/30/2023           4371      N444YX
#
#       Destination Airport Scheduled departure time Actual departure time  \
# 0                     SYR                    06:30                 06:29
# ...

# %%
departures_df
# Out:
#       Carrier Code Date (MM/DD/YYYY)  Flight Number Tail Number  \
# 0               G4        01/02/2020           1737       241NV
# 1               G4        01/03/2019           1720       226NV
# 2               G4        01/03/2021           1744       245NV
# 3               G4        01/03/2022            962       222NV
# 4               G4        01/03/2023            523       234NV
# ...            ...               ...            ...         ...
# 56537           YX        12/16/2023           4312      N128HQ
# 56538           YX        12/18/2021           5008      N127HQ
# 56539           YX        12/23/2023           4371      N102HQ
# 56540           YX        12/25/2021           5008      N425YX
# 56541           YX        12/30/2023           4371      N444YX
#
#       Destination Airport Scheduled departure time Actual departure time  \
# 0                     SYR                    06:30                 06:29
# ...

# %%
import os

cwd = os.getcwd() 

#departures
cwd += "/data/arrivals"
arrivals_df_list = []
for org in os.listdir(cwd):
    if not org.startswith("."):
        path = f"{cwd}/{org}"
        print(path)
        # for file in os.listdir(path):
            # if not file.startswith("."):
        file_path = f"{path}"
        temp_df = pd.read_csv(file_path, skiprows=7, skipfooter=1, engine="python")
        temp_df["Destination Airport"] = "SYR"
        arrivals_df_list.append(temp_df)
        # break
temp_df
# Out:
# /Users/saikeerthanpalavarapu/Documents/Syracuse/aa_su/sem - 2/IML/project/data/arrivals/Detailed_Statistics_Arrivals (16).csv
# /Users/saikeerthanpalavarapu/Documents/Syracuse/aa_su/sem - 2/IML/project/data/arrivals/Detailed_Statistics_Arrivals (4).csv
# /Users/saikeerthanpalavarapu/Documents/Syracuse/aa_su/sem - 2/IML/project/data/arrivals/Detailed_Statistics_Arrivals (8).csv
# /Users/saikeerthanpalavarapu/Documents/Syracuse/aa_su/sem - 2/IML/project/data/arrivals/Detailed_Statistics_Arrivals (9).csv
# /Users/saikeerthanpalavarapu/Documents/Syracuse/aa_su/sem - 2/IML/project/data/arrivals/Detailed_Statistics_Arrivals (5).csv
# /Users/saikeerthanpalavarapu/Documents/Syracuse/aa_su/sem - 2/IML/project/data/arrivals/Detailed_Statistics_Arrivals (10).csv
# /Users/saikeerthanpalavarapu/Documents/Syracuse/aa_su/sem - 2/IML/project/data/arrivals/Detailed_Statistics_Arrivals (2).csv
# ...

# %%
# arrivals_df = pd.concat(arrivals_df_list).reset_index(drop=True)
arrivals_df = pd.read_csv("./data/modified/arrivals.csv", index_col=0)
arrivals_df
# Out:
#       Carrier Code Date (MM/DD/YYYY)  Flight Number Tail Number  \
# 0               UA        01/01/2022           1282      N4901U
# 1               UA        01/01/2023            604      N814UA
# 2               UA        01/01/2023           2488      N38458
# 3               UA        01/01/2023           2645      N23721
# 4               UA        01/02/2022           1282      N4901U
# ...            ...               ...            ...         ...
# 69503           EV        12/16/2019           3977      N16976
# 69504           EV        12/17/2019           3977      N13978
# 69505           EV        12/18/2019           3977      N26545
# 69506           EV        12/22/2019           4388      N13903
# 69507           EV        12/30/2019           3205      N14902
#
#       Origin Airport Scheduled Arrival Time Actual Arrival Time  \
# 0                IAD                  23:10               00:01
# 1                DEN                  14:58               14:52
# ...

# %%
# arrivals_df.to_csv("./data/modified/arrivals.csv")
arrivals_df[arrivals_df["Origin Airport"]=="JFK"]["Carrier Code"].unique()
# Out:
# array(['B6', '9E', 'YX', 'OO'], dtype=object)

# %%
arrivals_df[arrivals_df["Origin Airport"]=="ORD"]["Carrier Code"].unique()
# Out:
# array(['UA', 'F9', 'MQ', 'EV', 'YX', 'AA', 'OO'], dtype=object)

# %%
departures_df
# Out:
#       Carrier Code Date (MM/DD/YYYY)  Flight Number Tail Number  \
# 0               G4        01/02/2020           1737       241NV
# 1               G4        01/03/2019           1720       226NV
# 2               G4        01/03/2021           1744       245NV
# 3               G4        01/03/2022            962       222NV
# 4               G4        01/03/2023            523       234NV
# ...            ...               ...            ...         ...
# 56537           YX        12/16/2023           4312      N128HQ
# 56538           YX        12/18/2021           5008      N127HQ
# 56539           YX        12/23/2023           4371      N102HQ
# 56540           YX        12/25/2021           5008      N425YX
# 56541           YX        12/30/2023           4371      N444YX
#
#       Destination Airport Scheduled departure time Actual departure time  \
# 0                     SYR                    06:30                 06:29
# ...

# %%
origin_airports_list = arrivals_df["Origin Airport"].unique().tolist()

# %%
origin_airports_list
# Out:
# ['IAD',
#  'DEN',
#  'EWR',
#  'ORD',
#  'ATL',
#  'DTW',
#  'LGA',
#  'MSP',
#  'MCO',
#  'RSW',
#  'TPA',
#  'MIA',
#  'RDU',
#  'ALB',
#  'JFK',
#  'BOS',
#  'FLL',
#  'DCA',
#  'DFW',
#  'CLT',
#  'PHL',
#  'SRQ',
#  'PIE',
#  'BNA',
#  'PGD',
#  'SFB',
#  'MYR',
#  'GSP',
#  'BWI']

# %%
initial_df = pd.read_csv("./CIS_662 _INITIAL_Predictions.csv")
initial_df
# Out:
#        DATE        DAY FLIGHT NUMBER ORIGIN DEPARTURE TIME ARRIVAL TIME  \
# 0   4/10/24  WEDNESDAY       UA 1400    ORD        6:52 PM      9:47 PM
# 1   4/10/24  WEDNESDAY       AA 3402    ORD        7:59 PM     10:52 PM
# 2   4/10/24  WEDNESDAY        B6 116    JFK        1:33 PM      2:50 PM
# 3   4/10/24  WEDNESDAY       DL 5182    JFK        2:55 PM      4:21 PM
# 4   4/10/24  WEDNESDAY       WN 5285    MCO       11:05 AM      1:45 PM
# 5   4/10/24  WEDNESDAY        B6 656    MCO        1:35 PM      4:25 PM
# 6   4/11/24   THURSDAY       UA 1400    ORD        6:52 PM      9:47 PM
# 7   4/11/24   THURSDAY       AA 3402    ORD        7:59 PM     10:52 PM
# 8   4/11/24   THURSDAY        B6 116    JFK        1:33 PM      2:50 PM
# 9   4/11/24   THURSDAY       DL 5182    JFK        2:55 PM      4:21 PM
# 10  4/11/24   THURSDAY       WN 5285    MCO       11:35 AM      2:20 PM
# 11  4/11/24   THURSDAY        B6 656    MCO        1:35 PM      4:25 PM
# ...

# %%
initial_df["ORIGIN"].unique()
# Out:
# array(['ORD', 'JFK', 'MCO'], dtype=object)

# %%
# initial_df["carrier"] = initial_df["FLIGHT NUMBER"].apply(lambda x: x[:2])
# initial_df[["carrier", "ORIGIN"]]
initial_df["carrier"].unique()
# Out:
# array(['UA', 'AA', 'B6', 'DL', 'WN'], dtype=object)

# %%
# initial_df["test"] = initial_df["carrier"].str.cat(initial_df["ORIGIN"], sep=" ")
# Out:
# array(['UA ORD', 'AA ORD', 'B6 JFK', 'DL JFK', 'WN MCO', 'B6 MCO'],
#       dtype=object)

# %%
# ['UA ORD', 'AA ORD', 'B6 JFK', 'DL JFK', 'WN MCO', 'B6 MCO']

# %%
initial_df
# Out:
#        DATE        DAY FLIGHT NUMBER ORIGIN DEPARTURE TIME ARRIVAL TIME  \
# 0   4/10/24  WEDNESDAY       UA 1400    ORD        6:52 PM      9:47 PM
# 1   4/10/24  WEDNESDAY       AA 3402    ORD        7:59 PM     10:52 PM
# 2   4/10/24  WEDNESDAY        B6 116    JFK        1:33 PM      2:50 PM
# 3   4/10/24  WEDNESDAY       DL 5182    JFK        2:55 PM      4:21 PM
# 4   4/10/24  WEDNESDAY       WN 5285    MCO       11:05 AM      1:45 PM
# 5   4/10/24  WEDNESDAY        B6 656    MCO        1:35 PM      4:25 PM
# 6   4/11/24   THURSDAY       UA 1400    ORD        6:52 PM      9:47 PM
# 7   4/11/24   THURSDAY       AA 3402    ORD        7:59 PM     10:52 PM
# 8   4/11/24   THURSDAY        B6 116    JFK        1:33 PM      2:50 PM
# 9   4/11/24   THURSDAY       DL 5182    JFK        2:55 PM      4:21 PM
# 10  4/11/24   THURSDAY       WN 5285    MCO       11:35 AM      2:20 PM
# 11  4/11/24   THURSDAY        B6 656    MCO        1:35 PM      4:25 PM
# ...

# %%
arrivals_df
# Out:
#       Carrier Code Date (MM/DD/YYYY)  Flight Number Tail Number  \
# 0               UA        01/01/2022           1282      N4901U
# 1               UA        01/01/2023            604      N814UA
# 2               UA        01/01/2023           2488      N38458
# 3               UA        01/01/2023           2645      N23721
# 4               UA        01/02/2022           1282      N4901U
# ...            ...               ...            ...         ...
# 69503           EV        12/16/2019           3977      N16976
# 69504           EV        12/17/2019           3977      N13978
# 69505           EV        12/18/2019           3977      N26545
# 69506           EV        12/22/2019           4388      N13903
# 69507           EV        12/30/2019           3205      N14902
#
#       Origin Airport Scheduled Arrival Time Actual Arrival Time  \
# 0                IAD                  23:10               00:01
# 1                DEN                  14:58               14:52
# ...

# %%
arrivals_df[arrivals_df["Origin Airport"].isin(['ORD', 'JFK', 'MCO']) & arrivals_df["Carrier Code"].isin()]
# Out:
#       Carrier Code Date (MM/DD/YYYY)  Flight Number Tail Number  \
# 3               UA        01/01/2023           2645      N23721
# 7               UA        01/02/2023           1998      N802UA
# 10              UA        01/03/2023           1998      N854UA
# 13              UA        01/04/2023           1998      N893UA
# 14              UA        01/05/2020           2012      N825UA
# ...            ...               ...            ...         ...
# 69439           EV        11/20/2019           4103      N609UX
# 69456           EV        11/24/2019           4461      N609UX
# 69496           EV        12/11/2019           4063      N607UX
# 69500           EV        12/14/2019           4486      N612UX
# 69502           EV        12/15/2019           4486      N616UX
#
#       Origin Airport Scheduled Arrival Time Actual Arrival Time  \
# 3                ORD                  23:57               23:47
# 7                ORD                  21:07               20:46
# ...

# %%
initial_df
# Out:
#        DATE        DAY FLIGHT NUMBER ORIGIN DEPARTURE TIME ARRIVAL TIME  \
# 0   4/10/24  WEDNESDAY       UA 1400    ORD        6:52 PM      9:47 PM
# 1   4/10/24  WEDNESDAY       AA 3402    ORD        7:59 PM     10:52 PM
# 2   4/10/24  WEDNESDAY        B6 116    JFK        1:33 PM      2:50 PM
# 3   4/10/24  WEDNESDAY       DL 5182    JFK        2:55 PM      4:21 PM
# 4   4/10/24  WEDNESDAY       WN 5285    MCO       11:05 AM      1:45 PM
# 5   4/10/24  WEDNESDAY        B6 656    MCO        1:35 PM      4:25 PM
# 6   4/11/24   THURSDAY       UA 1400    ORD        6:52 PM      9:47 PM
# 7   4/11/24   THURSDAY       AA 3402    ORD        7:59 PM     10:52 PM
# 8   4/11/24   THURSDAY        B6 116    JFK        1:33 PM      2:50 PM
# 9   4/11/24   THURSDAY       DL 5182    JFK        2:55 PM      4:21 PM
# 10  4/11/24   THURSDAY       WN 5285    MCO       11:35 AM      2:20 PM
# 11  4/11/24   THURSDAY        B6 656    MCO        1:35 PM      4:25 PM
# ...

# %%
arrivals_df = pd.read_csv("./data/modified/arrivals.csv", index_col=0)
arrivals_df
# Out:
#       Carrier Code Date (MM/DD/YYYY)  Flight Number Tail Number  \
# 0               UA        01/01/2022           1282      N4901U
# 1               UA        01/01/2023            604      N814UA
# 2               UA        01/01/2023           2488      N38458
# 3               UA        01/01/2023           2645      N23721
# 4               UA        01/02/2022           1282      N4901U
# ...            ...               ...            ...         ...
# 69503           EV        12/16/2019           3977      N16976
# 69504           EV        12/17/2019           3977      N13978
# 69505           EV        12/18/2019           3977      N26545
# 69506           EV        12/22/2019           4388      N13903
# 69507           EV        12/30/2019           3205      N14902
#
#       Origin Airport Scheduled Arrival Time Actual Arrival Time  \
# 0                IAD                  23:10               00:01
# 1                DEN                  14:58               14:52
# ...

# %%
arrivals_df[arrivals_df["Origin Airport"].isin(["ORD", "MCO", "JFK"])].reset_index(drop=True).drop_duplicates().to_csv("./data/modified/arrivals_jfk_mco_ord.csv", index=False)

# %%
departure_df = pd.read_csv("./data/modified/departures.csv", index_col=0)
departure_df
# Out:
#       Carrier Code Date (MM/DD/YYYY)  Flight Number Tail Number  \
# 0               G4        01/02/2020           1737       241NV
# 1               G4        01/03/2019           1720       226NV
# 2               G4        01/03/2021           1744       245NV
# 3               G4        01/03/2022            962       222NV
# 4               G4        01/03/2023            523       234NV
# ...            ...               ...            ...         ...
# 56537           YX        12/16/2023           4312      N128HQ
# 56538           YX        12/18/2021           5008      N127HQ
# 56539           YX        12/23/2023           4371      N102HQ
# 56540           YX        12/25/2021           5008      N425YX
# 56541           YX        12/30/2023           4371      N444YX
#
#       Destination Airport Scheduled departure time Actual departure time  \
# 0                     SYR                    06:30                 06:29
# ...

# %%
departure_df = departure_df[departure_df["Origin Airport"].isin(["JFK", "ORD", "MCO"])].reset_index(drop=True)

# %%
departure_df
# Out:
#       Carrier Code Date (MM/DD/YYYY)  Flight Number Tail Number  \
# 0               9E        01/01/2019           5391      N8943A
# 1               9E        01/01/2020           5066      N980EV
# 2               9E        01/01/2021           4851      N296PQ
# 3               9E        01/01/2023           5190      N325PQ
# 4               9E        01/02/2019           5391      N840AY
# ...            ...               ...            ...         ...
# 17458           F9        12/30/2023           3792      N341FR
# 17459           F9        12/31/2020           1214      N232FR
# 17460           F9        12/31/2021           1214      N347FR
# 17461           F9        12/31/2022           1216      N235FR
# 17462           F9        12/31/2023           3792      N605FR
#
#       Destination Airport Scheduled departure time Actual departure time  \
# 0                     SYR                    10:05                 09:53
# ...

# %%
departure_df.to_csv("./data/modified/departures_jfk_mco_ord.csv", index = False)
