# %%
import pandas as pd

# %%
arrivals_df = pd.read_csv("./data/modified/arrivals_jfk_mco_ord.csv")
arrivals_df
# Out:
#       Carrier Code Date (MM/DD/YYYY)  Flight Number Tail Number  \
# 0               UA        01/01/2023           2645      N23721
# 1               UA        01/02/2023           1998      N802UA
# 2               UA        01/03/2023           1998      N854UA
# 3               UA        01/04/2023           1998      N893UA
# 4               UA        01/05/2020           2012      N825UA
# ...            ...               ...            ...         ...
# 23629           EV        11/20/2019           4103      N609UX
# 23630           EV        11/24/2019           4461      N609UX
# 23631           EV        12/11/2019           4063      N607UX
# 23632           EV        12/14/2019           4486      N612UX
# 23633           EV        12/15/2019           4486      N616UX
#
#       Origin Airport Scheduled Arrival Time Actual Arrival Time  \
# 0                ORD                  23:57               23:47
# 1                ORD                  21:07               20:46
# ...

# %%
arrivals_df.dtypes
# Out:
# Carrier Code                                object
# Date (MM/DD/YYYY)                           object
# Flight Number                                int64
# Tail Number                                 object
# Origin Airport                              object
# Scheduled Arrival Time                      object
# Actual Arrival Time                         object
# Scheduled Elapsed Time (Minutes)             int64
# Actual Elapsed Time (Minutes)                int64
# Arrival Delay (Minutes)                      int64
# Wheels-on Time                              object
# Taxi-In time (Minutes)                       int64
# Delay Carrier (Minutes)                      int64
# Delay Weather (Minutes)                      int64
# Delay National Aviation System (Minutes)     int64
# Delay Security (Minutes)                     int64
# Delay Late Aircraft Arrival (Minutes)        int64
# Destination Airport                         object
# dtype: object

# %%
departures_df = pd.read_csv("./data/modified/departures.csv", index_col=0)
departures_df
# Out:
#       Carrier Code Date (MM/DD/YYYY)  Flight Number Tail Number  \
# 0               G4        01/02/2020           1737       241NV
# 1               G4        01/03/2019           1720       226NV
# 2               G4        01/03/2021           1744       245NV
# 3               G4        01/03/2022            962       222NV
# 4               G4        01/03/2023            523       234NV
# ...            ...               ...            ...         ...
# 56537           YX        12/16/2023           4312      N128HQ
# 56538           YX        12/18/2021           5008      N127HQ
# 56539           YX        12/23/2023           4371      N102HQ
# 56540           YX        12/25/2021           5008      N425YX
# 56541           YX        12/30/2023           4371      N444YX
#
#       Destination Airport Scheduled departure time Actual departure time  \
# 0                     SYR                    06:30                 06:29
# ...

# %%
weather_df = pd.read_csv("./data/modified/weather_mco_ord_jfk_syr_tz.csv")
weather_df
# Out:
#         key  valid_time_gmt day_ind  temp  wx_icon  icon_extd      wx_phrase  \
# 0       MCO      1546321980       N  69.0     29.0     2900.0  Partly Cloudy
# 1       MCO      1546325580       N  67.0     33.0     3300.0           Fair
# 2       MCO      1546329180       N  66.0     33.0     3300.0           Fair
# 3       MCO      1546331160       N  65.0     20.0     2000.0            Fog
# 4       MCO      1546331700       N  65.0     33.0     3300.0           Fair
# ...     ...             ...     ...   ...      ...        ...            ...
# 219795  SYR      1712523240       D  58.0     34.0     3400.0           Fair
# 219796  SYR      1712526840       D  57.0     34.0     3400.0           Fair
# 219797  SYR      1712530440       D  56.0     34.0     3400.0           Fair
# 219798  SYR      1712534040       N  50.0     33.0     3300.0           Fair
# 219799  SYR      1712537640       N  47.0     33.0     3300.0           Fair
#
# ...

# %%
weather_df.dtypes
# Out:
# key                object
# valid_time_gmt      int64
# day_ind            object
# temp              float64
# wx_icon           float64
# icon_extd         float64
# wx_phrase          object
# dewPt             float64
# heat_index        float64
# rh                float64
# pressure          float64
# vis               float64
# wc                float64
# wdir              float64
# wdir_cardinal      object
# wspd              float64
# precip_hrly       float64
# uv_desc            object
# feels_like        float64
# uv_index          float64
# clds               object
# date_time          object
# dtype: object

# %%
weather_df["date_time"] = pd.to_datetime(weather_df["date_time"])
weather_df
# Out:
#         key  valid_time_gmt day_ind  temp  wx_icon  icon_extd      wx_phrase  \
# 0       MCO      1546321980       N  69.0     29.0     2900.0  Partly Cloudy
# 1       MCO      1546325580       N  67.0     33.0     3300.0           Fair
# 2       MCO      1546329180       N  66.0     33.0     3300.0           Fair
# 3       MCO      1546331160       N  65.0     20.0     2000.0            Fog
# 4       MCO      1546331700       N  65.0     33.0     3300.0           Fair
# ...     ...             ...     ...   ...      ...        ...            ...
# 219795  SYR      1712523240       D  58.0     34.0     3400.0           Fair
# 219796  SYR      1712526840       D  57.0     34.0     3400.0           Fair
# 219797  SYR      1712530440       D  56.0     34.0     3400.0           Fair
# 219798  SYR      1712534040       N  50.0     33.0     3300.0           Fair
# 219799  SYR      1712537640       N  47.0     33.0     3300.0           Fair
#
# ...

# %%
weather_df.isna().sum()
# Out:
# key                   0
# valid_time_gmt        0
# day_ind               0
# temp                 10
# wx_icon              14
# icon_extd            14
# wx_phrase            14
# dewPt                19
# heat_index           19
# rh                   19
# pressure             54
# vis                  17
# wc                  191
# wdir              20154
# wdir_cardinal       187
# wspd                187
# precip_hrly           0
# uv_desc              56
# feels_like           64
# uv_index             56
# clds                 20
# date_time             0
# dtype: int64

# %%
len(weather_df.columns)
# Out:
# 22

# %%
corr = weather_df.corr(numeric_only=True)

# %%
corr_pairs = corr.unstack().sort_values(ascending=False).drop_duplicates().head(15)
corr_pairs
# Out:
# valid_time_gmt  valid_time_gmt    1.000000
# wc              feels_like        0.997847
# temp            heat_index        0.997177
# feels_like      temp              0.993734
#                 heat_index        0.993623
# wc              temp              0.993555
#                 heat_index        0.988525
# icon_extd       wx_icon           0.951590
# dewPt           feels_like        0.921275
# wc              dewPt             0.920601
# dewPt           temp              0.918927
#                 heat_index        0.917293
# icon_extd       vis               0.626319
# vis             wx_icon           0.570689
# uv_index        heat_index        0.427652
# dtype: float64

# %%
weather_corr_columns = set()
for pair in corr_pairs.index:
    weather_corr_columns.add(pair[0])
    weather_corr_columns.add(pair[1])
weather_corr_columns
# Out:
# {'dewPt',
#  'feels_like',
#  'heat_index',
#  'icon_extd',
#  'temp',
#  'uv_index',
#  'valid_time_gmt',
#  'vis',
#  'wc',
#  'wx_icon'}

# %%
weather_cat_cols = weather_df.select_dtypes(include=['object'])
weather_cat_cols
# Out:
#         key day_ind      wx_phrase wdir_cardinal uv_desc clds  \
# 0       MCO       N  Partly Cloudy             S     Low  SCT
# 1       MCO       N           Fair           SSW     Low  FEW
# 2       MCO       N           Fair           SSW     Low  FEW
# 3       MCO       N            Fog             S     Low  FEW
# 4       MCO       N           Fair          CALM     Low  FEW
# ...     ...     ...            ...           ...     ...  ...
# 219795  SYR       D           Fair           NNW     Low  CLR
# 219796  SYR       D           Fair            NW     Low  CLR
# 219797  SYR       D           Fair            NW     Low  CLR
# 219798  SYR       N           Fair            NW     Low  FEW
# 219799  SYR       N           Fair           NNW     Low  FEW
#
#                         date_time
# 0       2019-01-01 00:53:00-05:00
# 1       2019-01-01 01:53:00-05:00
# 2       2019-01-01 02:53:00-05:00
# 3       2019-01-01 03:26:00-05:00
# 4       2019-01-01 03:35:00-05:00
# ...

# %%
weather_df.select_dtypes(include=['object'])
# Out:
#         key day_ind      wx_phrase wdir_cardinal uv_desc clds  \
# 0       MCO       N  Partly Cloudy             S     Low  SCT
# 1       MCO       N           Fair           SSW     Low  FEW
# 2       MCO       N           Fair           SSW     Low  FEW
# 3       MCO       N            Fog             S     Low  FEW
# 4       MCO       N           Fair          CALM     Low  FEW
# ...     ...     ...            ...           ...     ...  ...
# 219795  SYR       D           Fair           NNW     Low  CLR
# 219796  SYR       D           Fair            NW     Low  CLR
# 219797  SYR       D           Fair            NW     Low  CLR
# 219798  SYR       N           Fair            NW     Low  FEW
# 219799  SYR       N           Fair           NNW     Low  FEW
#
#                         date_time
# 0       2019-01-01 00:53:00-05:00
# 1       2019-01-01 01:53:00-05:00
# 2       2019-01-01 02:53:00-05:00
# 3       2019-01-01 03:26:00-05:00
# 4       2019-01-01 03:35:00-05:00
# ...
